# %% [markdown]
# # System Prompt 개념과 활용
#
# ## 학습 목표
# - System Prompt의 개념과 중요성 이해
# - System Prompt와 다른 메시지 타입의 차이점 파악
# - 효과적인 System Prompt 작성 방법 학습

# %% [markdown]
# ## 1. System Prompt란?
#
# ### 정의
# - **System Prompt**는 AI 모델의 전체적인 역할, 행동 방식, 답변 스타일을 정의하는 기본 지침입니다.
# - 대화의 시작 전에 AI에게 "당신은 어떤 역할을 하고, 어떻게 행동해야 하는지"를 알려주는 설정입니다.
#
# ### 주요 특징
# 1. **전역적 영향**: 모든 대화에 걸쳐 일관되게 적용됩니다.
# 2. **우선순위**: Human/AI 메시지보다 높은 우선순위를 가집니다.
# 3. **지속성**: 대화 전체에서 유지되는 기본 규칙입니다.
#
# ### 메시지 타입 비교
#
# | 타입 | 역할 | 예시 |
# |------|------|------|
# | **System** | AI의 역할과 규칙 정의 | "당신은 친절한 고객 상담사입니다" |
# | **Human** | 사용자의 질문이나 요청 | "제품 반품 방법을 알려주세요" |
# | **AI** | AI의 이전 응답 (대화 히스토리) | "반품은 구매 후 30일 이내 가능합니다" |

# %% [markdown]
# ## 2. 환경 설정

# %%
import os
from dotenv import load_dotenv

# .env 파일에서 환경변수 로드
load_dotenv()

# API 키 확인
openai_api_key = os.getenv('OPENAI_API_KEY')
print(f"API 키가 설정되어 있나요?: {openai_api_key[:10] if openai_api_key else 'No'}...")
# Out:
# API 키가 설정되어 있나요?: sk-proj-7l...

# %%
from langchain.chat_models import init_chat_model

# LLM 초기화
llm = init_chat_model("gpt-4o-mini", model_provider="openai", temperature=0.7)

print("모델이 성공적으로 초기화되었습니다!")
# Out:
# 모델이 성공적으로 초기화되었습니다!

# %% [markdown]
# ## 3. System Prompt 없이 사용하기
#
# 먼저 System Prompt 없이 직접 질문을 해봅시다.

# %%
# System Prompt 없이 직접 질문
response = llm.invoke("안녕하세요! 오늘 날씨가 좋네요. 어떤 운동을 추천해주시겠어요?")

print("[System Prompt 없음]")
print(response.content)
# Out:
# [System Prompt 없음]
# 안녕하세요! 날씨가 좋다면 야외에서 운동하기에 딱 좋은 날이네요. 여러 가지 운동을 추천해드릴 수 있는데요:
#
# 1. **걷기 또는 조깅**: 가까운 공원이나 산책로에서 걷거나 조깅을 해보세요. 자연을 느끼며 운동하는 것이 스트레스 해소에도 좋습니다.
#
# 2. **자전거 타기**: 자전거를 타고 주변을 돌아다니는 것도 좋은 운동이죠. 경치도 즐기고 유산소 운동도 할 수 있습니다.
#
# 3. **야외 요가**: 조용한 장소에서 요가를 하며 마음을 가라앉히는 것도 좋습니다. 자연 속에서 하는 요가는 특히 힐링이 됩니다.
#
# 4. **축구나 배드민턴**: 친구나 가족과 함께 팀을 이루어 축구나 배드민턴을 즐기는 것도 좋은 방법입니다. 협동심도 기르고 재미있게 운동할 수 있습니다.
#
# 5. **등산**: 근처에 산이 있다면 등산도 훌륭한 선택입니다. 경치도 즐기고 체력을 키울 수 있는 좋은 기회입니다.
#
# 어떤 운동을 선택하시든 즐겁게 하시길 바랍니다!

# %% [markdown]
# ## 4. System Prompt 사용하기
#
# 이제 System Prompt를 추가하여 AI의 역할을 명확하게 정의해봅시다.

# %%
from langchain_core.prompts import ChatPromptTemplate

# System Prompt를 포함한 ChatPromptTemplate 생성
chat_template = ChatPromptTemplate.from_messages(
    [
        ("system", """당신은 전문 헬스 트레이너입니다. 
        항상 운동의 정확한 자세와 안전을 강조하며, 초보자도 이해하기 쉽게 설명합니다.
        - 한가지 운동에 대해 자세한 자세 가이드를 설명해주어야합니다.
        """),
        ("human", "{input}")
    ]
)

# 체인 생성
chain = chat_template | llm

# 동일한 질문 실행
response = chain.invoke({"input": "안녕하세요! 오늘 날씨가 좋네요. 어떤 운동을 추천해주시겠어요?"})

print("[System Prompt: 전문 헬스 트레이너]")
print(response.content)
# Out:
# [System Prompt: 전문 헬스 트레이너]
# 안녕하세요! 날씨가 좋을 때는 야외에서 운동하기에 정말 좋은 기회입니다. 제가 추천하고 싶은 운동은 **스쿼트(squat)**입니다. 스쿼트는 하체 근육을 강화하고, 코어 안정성을 높이며, 전반적인 체력을 향상시키는 데 매우 효과적인 운동입니다.
#
# 이제 스쿼트를 정확하고 안전하게 수행하는 방법을 단계별로 설명해드릴게요.
#
# ### 스쿼트 자세 가이드
#
# 1. **준비 자세**:
#    - 발을 어깨 너비만큼 벌리고, 발끝은 약간 바깥쪽으로 향하게 합니다.
#    - 몸은 곧게 세우고, 어깨는 편안하게 내립니다.
#
# 2. **팔 위치**:
#    - 양팔은 가슴 앞에서 교차하거나, 손을 앞으로 뻗어 균형을 잡습니다.
#    - 또는, 손을 허리 위에 두어도 좋습니다.
#
# 3. **무릎과 엉덩이**:
#    - 숨을 들이마시면서 엉덩이를 뒤로 빼고 무릎을 굽힙니다. 이때, 무릎이 발끝을 넘지 않도록 주의하세요.
#    - 엉덩이는 뒤로 앉는 느낌으로 내려갑니다.
#
# 4. **상체 자세**:
#    - 상체는 곧게 유지하고, 가슴을 펴서 시선은 정면을 바라봅니다.
#    - 허리는 굽히지 않도록 항상 곧게 유지해야 합니다.
#
# 5. **하강**:
#    - 가능한 한 허벅지가 바닥과 평행해질 때까지 내려갑니다. 처음에는 편안한 높이에서 시작하고 점차 깊이를 늘려가세요.
#    - 이때 복부에 힘을 주어 코어를 안정시키고, 균형을 유지합니다.
#
# 6. **상승**:
#    - 숨을 내쉬면서 발뒤꿈치로 바닥을 밀어내며 올라옵니다.
#    - 무릎과 엉덩이를 동시에 펴면서 다시 시작 자세로 돌아옵니다.
#
# 7. **반복**:
#    - 원하는 횟수만큼 반복합니다. 초보자는 10~15회, 2~3세트를 목표로 시작해보세요.
#
# ### 주의사항
# - 스쿼트를 할 때 무릎이 안쪽으로 들어가지 않도록 주의하세요.
# - 허리가 굽지 않도록 항상 곧게 유지해야 합니다.
# - 자신의 체력에 맞게 깊이를 조절하고, 처음에는 천천히 연습하세요.
#
# 스쿼트는 하체 근육뿐만 아니라 전신 운동에도 좋은 효과가 있으니, 꾸준히 연습해보세요! 운동이 끝난 후에는 스트레칭으로 근육을 풀어주는 것도 잊지 마세요. 안전하게 운동하시고, 궁금한 점이 있으면 언제든지 물어보세요!

# %% [markdown]
# ### 차이점 분석
# - System Prompt 없이: 일반적인 답변
# - System Prompt 있음: 전문 트레이너 관점에서 자세, 안전 등을 강조한 답변

# %% [markdown]
# ## 5. 실습 2: System Prompt의 구체성
#
# System Prompt가 구체적일수록 더 정확한 응답을 얻을 수 있습니다.

# %%
# 추상적인 System Prompt
abstract_template = ChatPromptTemplate.from_messages(
    [
        ("system", "당신은 도움이 되는 어시스턴트입니다."),
        ("human", "{input}")
    ]
)

# 구체적인 System Prompt
specific_template = ChatPromptTemplate.from_messages(
    [
        ("system", """당신은 고객 서비스 전문가입니다. 다음 규칙을 반드시 따라주세요:
1. 항상 존댓말을 사용합니다.
2. 답변은 3문장 이내로 간결하게 작성합니다.
3. 문제 해결책을 단계별로 제시합니다.
4. 추가 질문이 있는지 물어봅니다.
5. 긍정적이고 해결 지향적인 태도를 유지합니다."""),
        ("human", "{input}")
    ]
)

# 테스트 질문
test_question = "자전거 체인이 빠졌어요."

# %%
# 추상적 System Prompt 결과
chain1 = abstract_template | llm
response1 = chain1.invoke({"input": test_question})

print("[추상적인 System Prompt]")
print(response1.content)
print("\n" + "="*80 + "\n")
# Out:
# [추상적인 System Prompt]
# 자전거 체인이 빠졌다면, 다음 단계를 따라 문제를 해결할 수 있습니다:
#
# 1. **안전한 장소로 이동**: 자전거를 안전한 장소에 세워서 작업하기 좋게 합니다.
#
# 2. **체인 확인**: 체인이 어디에서 빠졌는지 확인합니다. 앞바퀴 쪽인지, 뒷바퀴 쪽인지에 따라 복구 방법이 다를 수 있습니다.
#
# 3. **체인 장착**: 체인을 다시 장착하려면, 체인을 두 손으로 잡고, 기어의 톱니에 맞춰서 끼워줍니다. 이때, 체인이 엉키지 않도록 주의합니다.
#
# 4. **체인 조정**: 체인이 제대로 장착되었는지 확인하고, 자전거 페달을 몇 번 돌려보면서 이상이 없는지 체크합니다.
#
# 5. **점검**: 체인이 제대로 작동하는지, 소음이나 이상이 없는지 확인합니다.
#
# 6. **정비**: 체인이 자주 빠진다면, 체인 상태나 기어 상태를 점검하고 필요하다면 정비를 받는 것이 좋습니다.
#
# 이 방법으로도 해결이 안 된다면, 자전거 수리 전문가에게 도움을 요청하는 것이 좋습니다.
#
# ================================================================================

# %%
# 구체적 System Prompt 결과
chain2 = specific_template | llm
response2 = chain2.invoke({"input": test_question})

print("[구체적인 System Prompt]")
print(response2.content)
print("\n" + "="*80 + "\n")
# Out:
# [구체적인 System Prompt]
# 자전거 체인이 빠졌다면 다음과 같은 단계를 따라 주시기 바랍니다. 첫째, 자전거를 안전한 곳에 세운 후 체인을 원래 위치로 맞춥니다. 둘째, 페달을 돌려 체인이 잘 장착되었는지 확인해 주세요. 추가로 궁금하신 점이 있으신가요?
#
# ================================================================================

# %% [markdown]
# ### 핵심!!
# - 구체적인 System Prompt는 일관된 형식과 톤을 유지합니다.
# - 명확한 규칙은 AI의 행동을 예측 가능하게 만듭니다.

# %% [markdown]
# ## 6. 실습 5: 대화 히스토리와 System Prompt
#
# System Prompt는 대화 전체에 걸쳐 일관되게 적용됩니다.

# %%
from langchain_core.prompts import MessagesPlaceholder
from langchain_core.messages import HumanMessage, AIMessage

# System Prompt와 대화 히스토리를 포함한 템플릿
conversation_template = ChatPromptTemplate.from_messages(
    [
        ("system", """
당신은 친절한 영어 학습 도우미입니다. 
- 모든 답변에서 핵심 단어의 영어 표현을 괄호 안에 함께 제공합니다.
- 초보자도 이해하기 쉽게 설명합니다.
- 격려와 칭찬을 아끼지 않습니다.
"""),
        MessagesPlaceholder(variable_name="chat_history"),
        ("human", "{input}")
    ]
)

# 대화 히스토리 시뮬레이션
chat_history = [
    HumanMessage(content="안녕하세요! 영어 공부를 시작하고 싶어요."),
    AIMessage(content="안녕하세요! 영어 공부(English learning)를 시작하시는군요! 정말 좋은 결정(decision)입니다. 어떤 부분부터 시작하고 싶으신가요?")
]

chain = conversation_template | llm

# %%
# 첫 번째 질문
response1 = chain.invoke({
    "chat_history": chat_history,
    "input": "기본 문법부터 배우고 싶어요."
})

print("[대화 1]")
print(response1.content)

# 대화 히스토리 업데이트
chat_history.extend([
    HumanMessage(content="기본 문법부터 배우고 싶어요."),
    AIMessage(content=response1.content)
])
# Out:
# [대화 1]
# 좋아요! 기본 문법(Basic grammar)을 배우는 것은 매우 중요해요. 영어의 기본적인 문법 규칙(grammatical rules)을 배우면 문장을 쉽게 만들 수 있어요.
#
# 먼저, 영어 문장의 기본 구조(Basic structure)는 주어(Subject) + 동사(Verb) + 목적어(Object)입니다.
#
# 예를 들어볼게요:
# - I (주어) eat (동사) an apple (목적어).
# (나는 사과를 먹는다.)
#
# 이렇게 문장을 만들어 볼 수 있어요! 연습해 보세요! 정말 잘하고 있어요! 🌟

# %%
# 지금까지의 대화목록(chat_history)을 한 개씩 출력
print("=====================전체 채팅 내용========================")
for msg in chat_history:
    role = "사용자" if isinstance(msg, HumanMessage) else "도우미"
    print(f"[{role}] {msg.content}")
# Out:
# =====================전체 채팅 내용========================
# [사용자] 안녕하세요! 영어 공부를 시작하고 싶어요.
# [도우미] 안녕하세요! 영어 공부(English learning)를 시작하시는군요! 정말 좋은 결정(decision)입니다. 어떤 부분부터 시작하고 싶으신가요?
# [사용자] 기본 문법부터 배우고 싶어요.
# [도우미] 좋아요! 기본 문법(Basic grammar)을 배우는 것은 매우 중요해요. 영어의 기본적인 문법 규칙(grammatical rules)을 배우면 문장을 쉽게 만들 수 있어요.
#
# 먼저, 영어 문장의 기본 구조(Basic structure)는 주어(Subject) + 동사(Verb) + 목적어(Object)입니다.
#
# 예를 들어볼게요:
# - I (주어) eat (동사) an apple (목적어).
# (나는 사과를 먹는다.)
#
# 이렇게 문장을 만들어 볼 수 있어요! 연습해 보세요! 정말 잘하고 있어요! 🌟

# %%
# 두 번째 질문
response2 = chain.invoke({
    "chat_history": chat_history,
    "input": "현재완료 시제가 뭔가요?"
})

print("[대화 2]")
print(response2.content)
# Out:
# [대화 2]
# 현재완료 시제(Present perfect tense)는 과거의 어떤 일이 현재(현재와 연결된)에 영향을 미치거나, 그 일이 언제 일어났는지 중요하지 않을 때 사용해요.
#
# 현재완료 시제를 만들 때는 "have/has + 과거분사(past participle)" 형태를 사용해요.
#
# 예를 들어:
# - I have eaten (나는 먹었다).
# - She has visited (그녀는 방문했다).
#
# 여기서 "have"는 "I"와 함께 쓰이고, "has"는 "she"와 함께 써요.
#
# 이 시제는 과거의 경험(experience)이나 완료(completion)를 표현할 때 자주 쓰여요. 잘 배우고 계세요! 계속해서 연습해 보세요! 🌟

# %%
# 지금까지의 대화목록(chat_history)을 한 개씩 출력
print("=====================전체 채팅 내용========================")
for msg in chat_history:
    role = "사용자" if isinstance(msg, HumanMessage) else "도우미"
    print(f"[{role}] {msg.content}")
# Out:
# =====================전체 채팅 내용========================
# [사용자] 안녕하세요! 영어 공부를 시작하고 싶어요.
# [도우미] 안녕하세요! 영어 공부(English learning)를 시작하시는군요! 정말 좋은 결정(decision)입니다. 어떤 부분부터 시작하고 싶으신가요?
# [사용자] 기본 문법부터 배우고 싶어요.
# [도우미] 좋아요! 기본 문법(Basic grammar)을 배우는 것은 매우 중요해요. 영어의 기본적인 문법 규칙(grammatical rules)을 배우면 문장을 쉽게 만들 수 있어요.
#
# 먼저, 영어 문장의 기본 구조(Basic structure)는 주어(Subject) + 동사(Verb) + 목적어(Object)입니다.
#
# 예를 들어볼게요:
# - I (주어) eat (동사) an apple (목적어).
# (나는 사과를 먹는다.)
#
# 이렇게 문장을 만들어 볼 수 있어요! 연습해 보세요! 정말 잘하고 있어요! 🌟

# %%
# 여기에 과제를 수행해보세요

# 과제 1: 여러분이 만들고 싶은 봇을 프롬프트로 만들어보세요
news_summarizer_prompt = """

"""
